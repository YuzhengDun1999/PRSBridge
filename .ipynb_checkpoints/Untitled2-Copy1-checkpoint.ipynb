# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
eig_val = np.load("eigval1000_1.npy")## when LD matrix is full rank

# %%
plt.semilogy(eig_val);
##convergence iteration is between 1000,1500, the largest beta is 0.01091

# %%
eig_val_ld = np.load("eig_val1000_ld.npy")
plt.semilogy(eig_val_ld);

# %%
eig_val_1 = np.load("eigval1000_point5.npy") ## when LD matrix is full rank
plt.semilogy(eig_val_1) 
##after 10000 iterations, the difference between beta_scaled and inv(Phi).dot(b) is 0.0219,
##after 20000 iterations, 1.47e-05, after 30000 iterations, 4.49e-06.
##after 40000 iterations, 4.49e-06

# %%
eig_val_ld_1 = np.load("eigval1000_ld_point5.npy") ## when LD matrix is full rank
plt.semilogy(eig_val_ld_1)

# %%
eig_val_2 = np.load("eigval1000_point2.npy") ## when only include 0.2 percent eigenvalues
plt.semilogy(eig_val_2) ##cannot converge within 10000 iterations, after 20000 iterations,
# the difference between beta_scaled and inv(Phi).dot(b) is 0.0422769

# %%
eig_val_ld_2 = np.load("eigval1000_ld_point2.npy") ## when only include 0.2 percent eigenvalues
plt.semilogy(eig_val_ld_2)

# %%
eig_val_05 = np.load("eigval1000_point05.npy") ## when only include 0.05 percent eigenvalues
plt.semilogy(eig_val_05) ##can converge within 5000 iterations
#rtol=3.3376e-09, the difference between beta_scaled and inverse(phi).dot(b) is 
#small enough after 1500 iterations, which is 2.762e-05. The difference is 2.3734e-05 after
#I set the maxiter=20000. 2.46e-05 when maxiter=30000

# %%
eig_val_ld_05 = np.load("eigval1000_ld_point05.npy") ## when only include 0.05 percent eigenvalues
plt.semilogy(eig_val_ld_05)
