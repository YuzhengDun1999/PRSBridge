# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
eig_val = np.load("eigval.npy")

# %%
plt.semilogy(eig_val);## when only include 0.5 percent eigenvalues
##can converge within 500 iterations, the largest beta value is 4094.4221

# %%
eig_val_ld = np.load("eigval_ld.npy")##eigenvalue of full rank ld matrix
plt.semilogy(eig_val_ld);

# %%
eig_val_1 = np.load("eigval_1.npy") ## when only include 0.5 percent eigenvalues
plt.semilogy(eig_val_1);
##convergence iteration is between 1000,1500, the largest beta is 0.03

# %%
eig_val_ld = np.load("eigval_ld_1.npy")##eigenvalue of 0.5 ld matrix
plt.semilogy(eig_val_ld);

# %%
eig_val_2 = np.load("eigval_point2.npy") ## when only include 0.2 percent eigenvalues
plt.semilogy(eig_val_2); ##can converge within 500 iterations
### largest beta is 4682.75

# %%
eig_val_ld = np.load("eigval_ld_point2.npy")##eigenvalue of 0.2 ld matrix
plt.semilogy(eig_val_ld);
